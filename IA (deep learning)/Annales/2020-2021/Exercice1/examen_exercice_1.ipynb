# %%
import numpy as np
import matplotlib.pyplot as plt    

data = np.genfromtxt("data_1D_examen.csv", delimiter=",")
nRow, nCol = data.shape
print(f"There are {nRow} rows and {nCol} columns")
# Out:
# There are 250 rows and 2 columns

# %%
x_data = data[:, 0]
y_data = data[:, 1]

# %%
plt.plot(x_data, y_data,".")
plt.show()

# %% [markdown]
# # Exercice

# %% [markdown]
# Entrainer un réseau de neurones afin de prédire des valeurs de y à partir de valeurs de x pour avoir un comportement similaire à celui des données fournies. On tracera l'évolution des éléments de suivi de l'entrainement (fonction de perte, etc.) en fonction du nombre d’étapes d’entrainement (epoch) pour des données d’entrainement et des données de validation.
#
# Commenter sur papier votre démarche pour résoudre cet exercice.
