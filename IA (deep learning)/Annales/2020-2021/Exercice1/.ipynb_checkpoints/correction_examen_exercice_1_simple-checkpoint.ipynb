# %%
import numpy as np
import matplotlib.pyplot as plt    

data = np.genfromtxt("data_1D_examen.csv", delimiter=",")
nRow, nCol = data.shape
print(f"There are {nRow} rows and {nCol} columns")
# Out:
# There are 250 rows and 2 columns

# %%
nbx_train = 175

x_train = data[:nbx_train, 0]
y_train = data[:nbx_train, 1]

x_test = data[nbx_train:, 0]
y_test = data[nbx_train:, 1]
nbx_test = np.size(x_test)

# %%
plt.plot(x_train, y_train,".")
plt.show()

# %%
plt.plot(x_test, y_test,".")
plt.show()

# %%
train_data = x_train.reshape((nbx_train,1))
train_targets = y_train
test_data = x_test.reshape((nbx_test,1))
test_targets = y_test

# %%
train_data.shape
# Out:
# (175, 1)

# %%
train_targets.shape
# Out:
# (175,)

# %%
train_targets[:10]
# Out:
# array([-0.7781823 ,  0.70382366, -0.3545493 , -0.37109354, -0.6861999 ,
#         0.21742965,  0.20468521,  0.84132929,  0.5152027 ,  0.26405024])

# %%
test_data.shape
# Out:
# (75, 1)

# %%
test_targets.shape
# Out:
# (75,)

# %% [markdown]
# **Model definition**

# %%
from tensorflow import keras
from tensorflow.keras import layers

def build_model():
    model = keras.Sequential([
        layers.Dense(512, activation="relu"),
        layers.Dense(512, activation="relu"),
        layers.Dense(1)
    ])
    model.compile(optimizer="rmsprop", loss="mse", metrics=["mae"])
    return model

# %%
model = build_model()
history = model.fit(train_data,
                    train_targets,
                    epochs=800,
                    batch_size=16,
                    validation_data=(test_data, test_targets))
# Out:
# Epoch 1/800
# 11/11 [==============================] - 3s 62ms/step - loss: 0.5673 - mae: 0.5336 - val_loss: 0.3346 - val_mae: 0.4823
# Epoch 2/800
# 11/11 [==============================] - 0s 19ms/step - loss: 0.2403 - mae: 0.4010 - val_loss: 0.2449 - val_mae: 0.4245
# Epoch 3/800
# 11/11 [==============================] - 0s 18ms/step - loss: 0.1910 - mae: 0.3516 - val_loss: 0.2078 - val_mae: 0.3950
# Epoch 4/800
# 11/11 [==============================] - 0s 18ms/step - loss: 0.2593 - mae: 0.4130 - val_loss: 0.1973 - val_mae: 0.3755
# Epoch 5/800
# 11/11 [==============================] - 0s 18ms/step - loss: 0.1493 - mae: 0.3165 - val_loss: 0.2146 - val_mae: 0.3916
# Epoch 6/800
# 11/11 [==============================] - 0s 19ms/step - loss: 0.2703 - mae: 0.3964 - val_loss: 0.1743 - val_mae: 0.3474
# Epoch 7/800
# 11/11 [==============================] - 0s 20ms/step - loss: 0.1375 - mae: 0.3048 - val_loss: 0.1900 - val_mae: 0.3582
# Epoch 8/800
# 11/11 [==============================] - 0s 19ms/step - loss: 0.1553 - mae: 0.3080 - val_loss: 0.3075 - val_mae: 0.4287
# Epoch 9/800
# 11/11 [==============================] - 0s 15ms/step - loss: 0.1256 - mae: 0.2812 - val_loss: 0.2198 - val_mae: 0.3674
# Epoch 10/800
# 11/11 [==============================] - 0s 18ms/step - loss: 0.1788 - mae: 0.3224 - val_loss: 0.1593 - val_mae: 0.3258
# Epoch 11/800
# 11/11 [==============================] - 0s 17ms/step - loss: 0.1546 - mae: 0.2954 - val_loss: 0.1623 - val_mae: 0.3315
# Epoch 12/800
# 11/11 [==============================] - 0s 18ms/step - loss: 0.1284 - mae: 0.2823 - val_loss: 0.3450 - val_mae: 0.4204
# Epoch 13/800
# 11/11 [==============================] - 0s 17ms/step - loss: 0.1351 - mae: 0.2873 - val_loss: 0.1547 - val_mae: 0.3249
# Epoch 14/800
# 11/11 [==============================] - 0s 18ms/step - loss: 0.1273 - mae: 0.2856 - val_loss: 0.3420 - val_mae: 0.4441
# Epoch 15/800
# 11/11 [==============================] - 0s 18ms/step - loss: 0.1444 - mae: 0.2935 - val_loss: 0.1556 - val_mae: 0.3205
# Epoch 16/800
# 11/11 [==============================] - 0s 19ms/step - loss: 0.1148 - mae: 0.2677 - val_loss: 0.1872 - val_mae: 0.3344
# Epoch 17/800
# 11/11 [==============================] - 0s 17ms/step - loss: 0.1244 - mae: 0.2726 - val_loss: 0.1823 - val_mae: 0.3396
# Epoch 18/800
# 11/11 [==============================] - 0s 17ms/step - loss: 0.1232 - mae: 0.2817 - val_loss: 0.1718 - val_mae: 0.3242
# Epoch 19/800
# 11/11 [==============================] - 0s 18ms/step - loss: 0.1196 - mae: 0.2790 - val_loss: 0.1540 - val_mae: 0.3172
# Epoch 20/800
# 11/11 [==============================] - 0s 19ms/step - loss: 0.1229 - mae: 0.2720 - val_loss: 0.1707 - val_mae: 0.3306
# Epoch 21/800
# 11/11 [==============================] - 0s 19ms/step - loss: 0.1172 - mae: 0.2698 - val_loss: 0.1536 - val_mae: 0.3151
# Epoch 22/800
# 11/11 [==============================] - 0s 19ms/step - loss: 0.1260 - mae: 0.2807 - val_loss: 0.1896 - val_mae: 0.3300
# Epoch 23/800
# 11/11 [==============================] - 0s 17ms/step - loss: 0.1053 - mae: 0.2560 - val_loss: 0.1540 - val_mae: 0.3131
# Epoch 24/800
# 11/11 [==============================] - 0s 18ms/step - loss: 0.1300 - mae: 0.2840 - val_loss: 0.1540 - val_mae: 0.3192
# Epoch 25/800
# 11/11 [==============================] - 0s 18ms/step - loss: 0.1072 - mae: 0.2607 - val_loss: 0.2301 - val_mae: 0.3501
# Epoch 26/800
# 11/11 [==============================] - 0s 18ms/step - loss: 0.1184 - mae: 0.2718 - val_loss: 0.1535 - val_mae: 0.3212
# Epoch 27/800
# 11/11 [==============================] - 0s 18ms/step - loss: 0.1133 - mae: 0.2720 - val_loss: 0.1530 - val_mae: 0.3106
# Epoch 28/800
# 11/11 [==============================] - 0s 17ms/step - loss: 0.1138 - mae: 0.2622 - val_loss: 0.1500 - val_mae: 0.3148
# Epoch 29/800
# 11/11 [==============================] - 0s 19ms/step - loss: 0.1109 - mae: 0.2646 - val_loss: 0.1559 - val_mae: 0.3054
# Epoch 30/800
# 11/11 [==============================] - 0s 21ms/step - loss: 0.1077 - mae: 0.2593 - val_loss: 0.1519 - val_mae: 0.3213
# Epoch 31/800
# 11/11 [==============================] - 0s 18ms/step - loss: 0.1115 - mae: 0.2693 - val_loss: 0.1479 - val_mae: 0.3167
# Epoch 32/800
# 11/11 [==============================] - 0s 18ms/step - loss: 0.1035 - mae: 0.2506 - val_loss: 0.1520 - val_mae: 0.3013
# Epoch 33/800
# 11/11 [==============================] - 0s 16ms/step - loss: 0.1012 - mae: 0.2543 - val_loss: 0.2048 - val_mae: 0.3311
# Epoch 34/800
# 11/11 [==============================] - 0s 17ms/step - loss: 0.1039 - mae: 0.2492 - val_loss: 0.1486 - val_mae: 0.2999
# Epoch 35/800
# 11/11 [==============================] - 0s 18ms/step - loss: 0.0985 - mae: 0.2411 - val_loss: 0.1656 - val_mae: 0.3025
# Epoch 36/800
# 11/11 [==============================] - 0s 18ms/step - loss: 0.0995 - mae: 0.2422 - val_loss: 0.1480 - val_mae: 0.2934
# Epoch 37/800
# 11/11 [==============================] - 0s 19ms/step - loss: 0.0993 - mae: 0.2420 - val_loss: 0.1389 - val_mae: 0.2872
# Epoch 38/800
# 11/11 [==============================] - 0s 18ms/step - loss: 0.0958 - mae: 0.2395 - val_loss: 0.1472 - val_mae: 0.2832
# Epoch 39/800
# 11/11 [==============================] - 0s 18ms/step - loss: 0.0951 - mae: 0.2418 - val_loss: 0.1411 - val_mae: 0.2794
# Epoch 40/800
# 11/11 [==============================] - 0s 18ms/step - loss: 0.0846 - mae: 0.2208 - val_loss: 0.1310 - val_mae: 0.2735
# Epoch 41/800
# 11/11 [==============================] - 0s 18ms/step - loss: 0.0902 - mae: 0.2231 - val_loss: 0.1306 - val_mae: 0.2737
# Epoch 42/800
# 11/11 [==============================] - 0s 18ms/step - loss: 0.0777 - mae: 0.2183 - val_loss: 0.1598 - val_mae: 0.2974
# Epoch 43/800
# 11/11 [==============================] - 0s 19ms/step - loss: 0.0983 - mae: 0.2388 - val_loss: 0.1357 - val_mae: 0.2798
# Epoch 44/800
# 11/11 [==============================] - 0s 15ms/step - loss: 0.0864 - mae: 0.2223 - val_loss: 0.1276 - val_mae: 0.2716
# Epoch 45/800
# 11/11 [==============================] - 0s 17ms/step - loss: 0.0934 - mae: 0.2321 - val_loss: 0.1314 - val_mae: 0.2738
# Epoch 46/800
# 11/11 [==============================] - 0s 18ms/step - loss: 0.0870 - mae: 0.2206 - val_loss: 0.1318 - val_mae: 0.2718
# Epoch 47/800
# 11/11 [==============================] - 0s 17ms/step - loss: 0.0818 - mae: 0.2171 - val_loss: 0.1271 - val_mae: 0.2654
# Epoch 48/800
# 11/11 [==============================] - 0s 19ms/step - loss: 0.0846 - mae: 0.2225 - val_loss: 0.1249 - val_mae: 0.2661
# Epoch 49/800
# 11/11 [==============================] - 0s 19ms/step - loss: 0.0794 - mae: 0.2066 - val_loss: 0.1499 - val_mae: 0.2715
# Epoch 50/800
# 11/11 [==============================] - 0s 17ms/step - loss: 0.0823 - mae: 0.2137 - val_loss: 0.1380 - val_mae: 0.2987
# Epoch 51/800
# 11/11 [==============================] - 0s 18ms/step - loss: 0.0868 - mae: 0.2244 - val_loss: 0.1220 - val_mae: 0.2614
# Epoch 52/800
# 11/11 [==============================] - 0s 18ms/step - loss: 0.0837 - mae: 0.2192 - val_loss: 0.1242 - val_mae: 0.2626
# Epoch 53/800
# 11/11 [==============================] - 0s 19ms/step - loss: 0.0806 - mae: 0.2127 - val_loss: 0.1226 - val_mae: 0.2596
# Epoch 54/800
# 11/11 [==============================] - 0s 17ms/step - loss: 0.0813 - mae: 0.2141 - val_loss: 0.1231 - val_mae: 0.2712
# Epoch 55/800
# 11/11 [==============================] - 0s 17ms/step - loss: 0.0842 - mae: 0.2242 - val_loss: 0.1288 - val_mae: 0.2702
# Epoch 56/800
# 11/11 [==============================] - 0s 18ms/step - loss: 0.0794 - mae: 0.2102 - val_loss: 0.1205 - val_mae: 0.2604
# Epoch 57/800
# 11/11 [==============================] - 0s 17ms/step - loss: 0.0825 - mae: 0.2153 - val_loss: 0.1217 - val_mae: 0.2609
# Epoch 58/800
# 11/11 [==============================] - 0s 19ms/step - loss: 0.0797 - mae: 0.2132 - val_loss: 0.1193 - val_mae: 0.2575
# Epoch 59/800
# 11/11 [==============================] - 0s 17ms/step - loss: 0.0800 - mae: 0.2131 - val_loss: 0.1185 - val_mae: 0.2535
# Epoch 60/800
# 11/11 [==============================] - 0s 18ms/step - loss: 0.0805 - mae: 0.2119 - val_loss: 0.1240 - val_mae: 0.2583
# Epoch 61/800
# 11/11 [==============================] - 0s 18ms/step - loss: 0.0808 - mae: 0.2157 - val_loss: 0.1211 - val_mae: 0.2634
# Epoch 62/800
# 11/11 [==============================] - 0s 18ms/step - loss: 0.0779 - mae: 0.2077 - val_loss: 0.1244 - val_mae: 0.2641
# Epoch 63/800
# 11/11 [==============================] - 0s 17ms/step - loss: 0.0798 - mae: 0.2106 - val_loss: 0.1203 - val_mae: 0.2666
# Epoch 64/800
# 11/11 [==============================] - 0s 18ms/step - loss: 0.0801 - mae: 0.2119 - val_loss: 0.1184 - val_mae: 0.2570
# Epoch 65/800
# 11/11 [==============================] - 0s 17ms/step - loss: 0.0799 - mae: 0.2165 - val_loss: 0.1283 - val_mae: 0.2889
# Epoch 66/800
# 11/11 [==============================] - 0s 17ms/step - loss: 0.0784 - mae: 0.2070 - val_loss: 0.1206 - val_mae: 0.2646
# Epoch 67/800
# 11/11 [==============================] - 0s 18ms/step - loss: 0.0795 - mae: 0.2138 - val_loss: 0.1174 - val_mae: 0.2553
# Epoch 68/800
# 11/11 [==============================] - 0s 18ms/step - loss: 0.0773 - mae: 0.2077 - val_loss: 0.1210 - val_mae: 0.2575
# Epoch 69/800
# 11/11 [==============================] - 0s 19ms/step - loss: 0.0772 - mae: 0.2072 - val_loss: 0.1196 - val_mae: 0.2601
# Epoch 70/800
# 11/11 [==============================] - 0s 19ms/step - loss: 0.0775 - mae: 0.2048 - val_loss: 0.1175 - val_mae: 0.2606
# Epoch 71/800
# 11/11 [==============================] - 0s 19ms/step - loss: 0.0800 - mae: 0.2163 - val_loss: 0.1222 - val_mae: 0.2723
# Epoch 72/800
# 11/11 [==============================] - 0s 17ms/step - loss: 0.0766 - mae: 0.2025 - val_loss: 0.1169 - val_mae: 0.2576
# Epoch 73/800
# 11/11 [==============================] - 0s 16ms/step - loss: 0.0774 - mae: 0.2105 - val_loss: 0.1179 - val_mae: 0.2628
# Epoch 74/800
# 11/11 [==============================] - 0s 13ms/step - loss: 0.0790 - mae: 0.2075 - val_loss: 0.1176 - val_mae: 0.2578
# Epoch 75/800
# 11/11 [==============================] - 0s 17ms/step - loss: 0.0776 - mae: 0.2071 - val_loss: 0.1193 - val_mae: 0.2642
# Epoch 76/800
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0853 - mae: 0.2215

# %%
history_dict = history.history
history_dict.keys()
# Out:
# dict_keys(['loss', 'mae', 'val_loss', 'val_mae'])

# %%
history_dict = history.history
loss_values = history_dict["loss"]
val_loss_values = history_dict["val_loss"]
epochs = range(1, len(loss_values) + 1)
plt.plot(epochs, loss_values, "r.", label="Training loss")
plt.plot(epochs, val_loss_values, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
debut_epochs = 100
epochs_restriction = range(debut_epochs+1, len(loss_values) + 1)
plt.plot(epochs_restriction, loss_values[debut_epochs:], "r.", label="Training loss")
plt.plot(epochs_restriction, val_loss_values[debut_epochs:], "b", label="Validation loss")
plt.title("Training and validation loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
plt.clf()
mae = history_dict["mae"]
val_mae = history_dict["val_mae"]
plt.plot(epochs, mae, "r.", label="Training MAE")
plt.plot(epochs, val_mae, "b", label="Validation MAE")
plt.title("Training and validation MAE")
plt.xlabel("Epochs")
plt.ylabel("MAE")
plt.legend()
plt.show()

# %%
plt.clf()
truncation = 10
plt.plot(epochs[truncation:], val_mae[truncation:], "b", label="Validation MAE")
plt.title("Validation MAE")
plt.xlabel("Epochs")
plt.ylabel("MAE")
plt.legend()
plt.show()

# %% [markdown]
# **Training the final model**

# %%
model = build_model()
model.fit(train_data, train_targets,
          epochs=500, batch_size=16, verbose=0)
test_mse_score, test_mae_score = model.evaluate(test_data, test_targets)
# Out:
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0075 - mae: 0.0677

# %%
test_mae_score
# Out:
# 0.0677468329668045

# %%
predictions = model.predict(test_data)
predictions.shape
# Out:
# 3/3 [==============================] - 0s 7ms/step
# (75, 1)

# %%
plt.plot(test_data,predictions[:,0],".")
plt.show()
